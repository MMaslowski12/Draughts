# %%
import math
import copy
# !pip install numpy
import numpy as np

# !pip install pillow
from PIL import Image, ImageColor
import IPython.display

from Piece import Piece
from Board import Board
from Engine import Engine, Game
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\oem\appdata\roaming\python\python38\site-packages (1.21.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow in c:\users\oem\appdata\roaming\python\python38\site-packages (8.3.1)

# %%
class SimpleBot():
    #note - I think max_depth should always be an even number as if else score from heura will be a score of an opposite player
    #so the algorithm will be looking for the most plausible option for the enemy
    #which is the complete opposite of what it should do
    def __init__(self, alpha_beta = True):
        self.alpha_beta = alpha_beta
        if alpha_beta:
            self.max_depth = 4
        else:
            self.max_depth = 2
        
    def pawn_kill_first(self, board, y, x, path, al_done):
        p_kill_list = []
        def pawn_kill_latter(self, board, y, x, path, al_done):
            nonlocal p_kill_list


            cont = 0
            pathsave = path
            if board.isBlack(y - 1, x - 1):
                if (y - 1, x - 1) not in al_done:
                    if board.isEmpty(y - 2, x - 2):
                        cont = 1

                        pawn_kill_latter(self, board, y - 2, x - 2, path + [[y - 2, x - 2]], al_done + [(y - 1, x - 1)])
            path = pathsave

            if board.isBlack(y + 1, x + 1):
                if (y + 1, x + 1) not in al_done:
                    if board.isEmpty(y + 2, x + 2):
                        cont = 1

                        pawn_kill_latter(self, board, y + 2, x + 2, path + [[y + 2, x + 2]], al_done + [(y + 1, x + 1)])
            path = pathsave


            if board.isBlack(y - 1, x + 1):
                if (y - 1,x + 1) not in al_done:
                    if board.isEmpty(y - 2, x + 2):
                        cont = 1

                        pawn_kill_latter(self, board, y - 2, x + 2, path + [[y - 2, x + 2]], al_done + [(y - 1, x + 1)])
            path=pathsave

            if board.isBlack(y + 1, x - 1):
                if (y + 1, x - 1) not in al_done:
                    if board.isEmpty(y + 2, x - 2):
                        cont = 1

                        pawn_kill_latter(self, board, y + 2, x - 2, path + [[y + 2, x - 2]], al_done + [(y + 1, x - 1 )])
            path=pathsave

            if cont == 0:

                p_kill_list += [path]
            
#_____________________________________________________________________________________________________________________________________
#_____________________________________________________________________________________________________________________________________        
        
        cont = 0
        pathsave=path
        if board.isBlack(y + 1, x - 1):
            if (y + 1, x - 1) not in al_done:
                if board.isEmpty(y + 2, x - 2):

                    cont = 1

                    pawn_kill_latter(self, board, y + 2, x - 2, path + [[y + 2, x - 2]], al_done + [(y + 1, x - 1)])
        path = pathsave
        
        if board.isBlack(y + 1, x + 1):
            if (y + 1, x + 1) not in al_done:
                if board.isEmpty(y + 2, x + 2):

                    cont = 1

                    pawn_kill_latter(self, board, y + 2, x + 2, path + [[y + 2, x + 2]], al_done + [(y + 1, x + 1)])
        path = pathsave
        
        
                
        return p_kill_list

# %%
class SimpleBot(SimpleBot):
    def king_kill_first(self, board, y, x, path, al_done):
        k_kill_list = []
        def king_kill_latter(self, board, y, x, path, al_done, last_kill):
            nonlocal k_kill_list
            cont = 0
            block = 0
            if last_kill != 1:
                for i in range (min(x, y) + 1):
                    if  not board.isEmpty(y - i - 1, x - i - 1):
                        if not board.isBlack(y - i - 1, x - i - 1):
                            block = i
                            break

                for i in range (block):
                    if board.isBlack(y - i - 1, x - i - 1):
                            if (y - i - 1, x - i - 1) not in al_done:
                                for j in range (i + 1 , block):
                                    if board.isBlack(y - j - 1, x - j - 1) and (y - j - 1, x - j - 1) not in al_done:
                                        break

                                    cont = 1
                                    king_kill_latter(self, board, y - j - 1, x - j - 1, path + [[y - j - 1, x - j - 1]], al_done + [(y - i - 1, x - i - 1)], 3)
                                break


            if last_kill != 3:
                for i in range (9 - max(x, y) + 1):
                    if not board.isEmpty(y + i + 1, x + i + 1):
                        if not board.isBlack(y + i + 1, x + i + 1):
                            block = i
                            break

                for i in range (block):
                    if board.isBlack(y + i + 1, x + i + 1):
                        if (y + i + 1, x + i + 1) not in al_done:
                            for j in range (i + 1 , block):
                                if board.isBlack(y + j + 1, x + j + 1) and (y + j + 1, x + j + 1) not in al_done:
                                    break

                                cont = 1
                                king_kill_latter(self, board, y + j + 1, x + j + 1, path + [[y + j + 1, x + j + 1]], al_done + [(y + i + 1, x + i + 1)], 1)
                            break



            if last_kill != 4:
                for i in range (min (x, 9 - y) + 1):
                    if not board.isEmpty(y + i + 1, x - i - 1):
                        if not board.isBlack(y + i + 1, x - i - 1):
                            block = i
                            break

                for i in range (block):
                    if board.isBlack(y + i + 1, x - i - 1):
                        if (y + i + 1, x - i - 1) not in al_done:
                            for j in range (i + 1 , block):
                                if board.isBlack(y + j + 1, x - j - 1) and (y + j + 1, x - j - 1) not in al_done:
                                    break

                                cont = 1
                                king_kill_latter(self, board, y + j + 1, x - j - 1, path + [[y + j + 1, x - j - 1]], al_done + [(y + i + 1, x - i - 1)], 2)
                            break        







            if last_kill != 2:
                for i in range (min (y, 9 - x) + 1):
                    if not board.isEmpty(y - i - 1, x + i + 1):
                        if not board.isBlack(y - i - 1, x + i + 1):
                            block = i
                            break

                for i in range (block):
                    if board.isBlack(y - i - 1, x + i + 1):
                        if (y - i - 1, x + i + 1) not in al_done:
                            for j in range (i + 1 , block):
                                if board.isBlack(y - j - 1, x + j + 1) and (y - j - 1, x + j + 1) not in al_done:
                                    break

                                cont = 1
                                king_kill_latter(self, board, y - j - 1, x + j + 1, path + [[y - j - 1, x + j + 1]], al_done + [(y - i - 1, x + i + 1)], 4)
                            break

            if cont == 0:
                k_kill_list += [path]
                
                
#_____________________________________________________________________________________________________________________________________
#_____________________________________________________________________________________________________________________________________        
        

        cont = 0
        block = 0
        for i in range (min(x, y)  + 1):
            if  not board.isEmpty(y - i - 1, x - i - 1):
                if not board.isBlack(y - i - 1, x - i - 1):
                    block = i
                    break
                    
        for i in range (block):
            if board.isBlack(y - i - 1, x - i - 1):
                    if (y - i - 1, x - i - 1) not in al_done:
                        for j in range (i + 1 , block):
                            if board.isBlack(y - j - 1, x - j - 1) and (y - j - 1, x - j - 1) not in al_done:
                                break

                            cont = 1
                            king_kill_latter(self, board, y - j - 1, x - j - 1, path + [[y - j - 1, x - j - 1]], al_done + [(y - i - 1, x - i - 1)], 3)
                        break
        
        
        
        for i in range (9 - max(x, y) + 1):
            if not board.isEmpty(y + i + 1, x + i + 1):
                if not board.isBlack(y + i + 1, x + i + 1):
                    block = i
                    break
                    
        for i in range (block):
            if board.isBlack(y + i + 1, x + i + 1):
                if (y + i + 1, x + i + 1) not in al_done:
                    for j in range (i + 1 , block):
                        if board.isBlack(y + j + 1, x + j + 1) and (y + j + 1, x + j + 1) not in al_done:
                            break

                        cont = 1
                        king_kill_latter(self, board, y + j + 1, x + j + 1, path + [[y + j + 1, x + j + 1]], al_done + [(y + i + 1, x + i + 1)], 1)
                break
                
           
        
        
        
        for i in range (min (x, 9 - y) + 1):
            if not board.isEmpty(y + i + 1, x - i - 1):
                if not board.isBlack(y + i + 1, x - i - 1):
                    block = i
                    break
                    
        for i in range (block):
            if board.isBlack(y + i + 1, x - i - 1):
                if (y + i + 1, x - i - 1) not in al_done:
                    for j in range (i + 1 , block):
                        if board.isBlack(y + j + 1, x - j - 1) and (y + j + 1, x - j - 1) not in al_done:
                            break

                        cont = 1
                        king_kill_latter(self, board, y + j + 1, x - j - 1, path + [[y + j + 1, x - j - 1]], al_done + [(y + i + 1, x - i - 1)], 2)
                    break        
        
        

        
        
        
        
        
        for i in range (min (y, 9 - x) + 1):
            if not board.isEmpty(y - i - 1, x + i + 1):
                if not board.isBlack(y - i - 1, x + i + 1):
                    block = i
                    break
                    
        for i in range (block):
            if board.isBlack(y - i - 1, x + i + 1):
                if (y - i - 1, x + i + 1) not in al_done:
                    for j in range (i + 1 , block):
                        
                        if board.isBlack(y - j - 1, x + j + 1) and (y - j - 1, x + j + 1) not in al_done:
                            break
                        print('x')
                        cont = 1
                        king_kill_latter(self, board, y - j - 1, x + j + 1, path + [[y - j - 1, x + j + 1]], al_done + [(y - i - 1, x + i + 1)], 4)
                    break
        
        
        
        return k_kill_list

# %%
class SimpleBot(SimpleBot):
    def kill_list(self, board):
        k_list = []
        for white in board.whites:
            if not white.king:
                x = self.pawn_kill_first(board, white.y, white.x, [[white.y, white.x]], [])
                

                if x != []:
                    k_list += x
            else:
                x = self.king_kill_first(board, white.y, white.x, [[white.y, white.x]], [])                

                if x != []:
                    k_list += x
        k_listn = []

        for i in k_list:

            new_element = []
            for j in i:

                new_element += [{'y': j[0], 'x': j[1]}]

                

            k_listn.append(new_element)
            
        return k_listn

# %%
class SimpleBot(SimpleBot):
    def moves_list(self, board):
        moves=[]
        for white in board.whites:
            if not white.king:
                if board.isEmpty(white.y + 1, white.x + 1):
                    moves += [[white.y, white.x, white.y + 1, white.x + 1]]
                if board.isEmpty(white.y + 1, white.x - 1):
                    moves += [[white.y, white.x, white.y + 1, white.x - 1]]
            else:
                for i in range (min(white.x,white.y)):
                    if board.isEmpty(white.y - i - 1,white.x - i - 1):
                        moves += [[white.y, white.x, white.y - i - 1, white.x - 1 - i]]
                    else: break

                for i in range (9 - max(white.x, white.y)):
                    if board.isEmpty(white.y + i + 1,white.x + i + 1):
                        moves += [[white.y, white.x, white.y + i + 1, white.x + 1 + i]]
                    else: break

                for i in range (min(white.x, 9 - white.y)):
                    if board.isEmpty(white.y + i + 1,white.x - i - 1):
                        moves += [[white.y, white.x, white.y + i + 1, white.x - 1 - i]]
                    else: break

                for i in range (min(white.y, 9 - white.x)):
                    if board.isEmpty(white.y - i - 1,white.x + i + 1):
                        moves += [[white.y, white.x, white.y - i - 1, white.x + 1 + i]]
                    else: break
                        
                    
        movesn = []
        for i in moves:
            new_element = []
            for j in range (int(len(i) / 2)):
                new_element += [{'y': i[2*j], 'x': i[2*j + 1]}]
            movesn += [new_element]
        return movesn

# %%
class SimpleBot(SimpleBot):
    def heura(self, board):
        #idea: i should change how much material difference matters depending on the stage of the game
        #1 additional when you have 2 left wins you the game but when you have all of them it is not that big of a deal
        score = 0
        scoreb = 0
        def heura_inner(self, board):
            score = 0
            for white in board.whites:
                if white.king:
                    score += 5
                else:
                    score += 1
                if white.y == 3:
                    score += 0.25
                if white.y == 4:
                    score += 0.5
                if white.y == 5:
                    score += 0.75
                if white.y == 6:
                    score += 1.1
                if white.y == 7:
                    score += 1.6
                if white.y == 8:
                    score += 3
                for mate in board.whites:
                    for i in [-1, 1]:
                        if mate.y == white.y - 1 and mate.x == white.x + i:
                            score += 0.25
                if white.x == 0 or white.x == 9:
                    score += 0.25
            return score
                
        
        score = heura_inner(self, board) - heura_inner(self, board.revert())
        return score

# %%
#
#OLD VERSION WITH NO ALPHA-BETA
#

class SimpleBot(SimpleBot):
    def old_get_board_score(self, board, depth, my_move):


        if depth == self.max_depth:
            return (self.heura(board), None)
        else:
            if board.kill_possible():
                moves = self.kill_list(board)
                
                
            else:
                moves = self.moves_list(board)

        result = -10000 if my_move else 10000
        optmove = None
        for move in moves:   

            potential_result = self.old_get_board_score(board.make_move(move), depth + 1, not my_move)[0] #add result as argument
            #if potenial >(or <, depending on max/min) result gained from depth above, abort action and return that old result
            

            if (my_move == (potential_result > result)):
                result = potential_result
                optmove = move


        return (result, optmove)
    
#
#OLD VERSION WITH NO ALPHA-BETA
#

# %%
class SimpleBot(SimpleBot):
    def get_board_score(self, board, depth, my_move, old_result):


        if depth == self.max_depth:
            return (self.heura(board), None)
        else:
            if board.kill_possible():
                moves = self.kill_list(board)
                
                
            else:
                moves = self.moves_list(board)
        #print(moves)
        #print('______')
        result = -10000 if my_move else 10000
        optmove = None
        for move in moves:  
            print(move)
            potential_result = self.get_board_score(board.make_move(move), depth + 1, not my_move, result)[0]
            if (potential_result >= old_result and my_move == 1) or (potential_result <= old_result and my_move == 0):
                return (old_result, move)

            if (my_move == (potential_result > result)):
                result = potential_result
                optmove = move


        return (result, optmove)

# %%
class SimpleBot(SimpleBot):
    def make_move(self, board):
        if self.alpha_beta:
            return self.get_board_score(board, 0, True, 10000)[1]
        else:
            return self.old_get_board_score(board, 0, True)[1]

# %%
bot = SimpleBot()
bot2 = SimpleBot(False)
game = Game(bot, bot2)
game.play_bots(True)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x22A5182F130>
# [{'y': 6, 'x': 4}, {'y': 7, 'x': 5}]
# True
# [{'y': 1, 'x': 5}, {'y': 3, 'x': 3}]
# False
# [{'y': 5, 'x': 5}, {'y': 7, 'x': 7}]
# True
# [{'y': 1, 'x': 3}, {'y': 3, 'x': 1}]
# False
# [{'y': 1, 'x': 1}, {'y': 3, 'x': 3}]
# False
# [{'y': 1, 'x': 3}, {'y': 3, 'x': 5}, {'y': 5, 'x': 3}]
# False
# [{'y': 5, 'x': 3}, {'y': 6, 'x': 4}]
# False
# x
# x
# x
# [{'y': 9, 'x': 1}, {'y': 4, 'x': 6}, {'y': 2, 'x': 4}]
# True
# [{'y': 9, 'x': 1}, {'y': 4, 'x': 6}, {'y': 1, 'x': 3}]
# True
# [{'y': 9, 'x': 1}, {'y': 4, 'x': 6}, {'y': 6, 'x': 8}]
# True
# [{'y': 9, 'x': 1}, {'y': 4, 'x': 6}, {'y': 7, 'x': 9}, {'y': 9, 'x': 7}, {'y': 7, 'x': 5}]
# True
# <PIL.Image.Image image mode=RGB size=400x400 at 0x22A507CB100>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1936/942091213.py in <module>
#       2 bot2 = SimpleBot(False)
#       3 game = Game(bot, bot2)
# ----> 4 game.play_bots(True)
#
# ~\PycharmProjects\checkers\Engine.py in play_bots(self, draw_board)
#      98
#      99         while self.continue_game:
# --> 100             self.bot_move(self.white, True, draw_board)
#     101             if not self.continue_game:
#     102                 break
#
# ~\PycharmProjects\checkers\Engine.py in bot_move(self, bot, is_white, draw_board)
#      45
#      46     def bot_move(self, bot, is_white, draw_board=True):
# ---> 47         move = bot.make_move(self.engine.board)
#      48
#      49         try:
#
# ~\AppData\Local\Temp/ipykernel_1936/4015402309.py in make_move(self, board)
#       2     def make_move(self, board):
#       3         if self.alpha_beta:
# ----> 4             return self.get_board_score(board, 0, True, 10000)[1]
#       5         else:
#       6             return self.old_get_board_score(board, 0, True)[1]
#
# ~\AppData\Local\Temp/ipykernel_1936/1921823223.py in get_board_score(self, board, depth, my_move, old_result)
#      19             print(move)
#      20             print(board.isEmpty(4,6))
# ---> 21             potential_result = self.get_board_score(board.make_move(move), depth + 1, not my_move, result)[0]
#      22             if (potential_result >= old_result and my_move == 1) or (potential_result <= old_result and my_move == 0):
#      23                 return (old_result, move)
#
# ~\AppData\Local\Temp/ipykernel_1936/1921823223.py in get_board_score(self, board, depth, my_move, old_result)
#      19             print(move)
#      20             print(board.isEmpty(4,6))
# ---> 21             potential_result = self.get_board_score(board.make_move(move), depth + 1, not my_move, result)[0]
#      22             if (potential_result >= old_result and my_move == 1) or (potential_result <= old_result and my_move == 0):
#      23                 return (old_result, move)
#
# ~\AppData\Local\Temp/ipykernel_1936/1921823223.py in get_board_score(self, board, depth, my_move, old_result)
#      19             print(move)
#      20             print(board.isEmpty(4,6))
# ---> 21             potential_result = self.get_board_score(board.make_move(move), depth + 1, not my_move, result)[0]
#      22             if (potential_result >= old_result and my_move == 1) or (potential_result <= old_result and my_move == 0):
#      23                 return (old_result, move)
#
# ~\AppData\Local\Temp/ipykernel_1936/1921823223.py in get_board_score(self, board, depth, my_move, old_result)
#      19             print(move)
#      20             print(board.isEmpty(4,6))
# ---> 21             potential_result = self.get_board_score(board.make_move(move), depth + 1, not my_move, result)[0]
#      22             if (potential_result >= old_result and my_move == 1) or (potential_result <= old_result and my_move == 0):
#      23                 return (old_result, move)
#
# ~\PycharmProjects\checkers\Board.py in make_move(self, moves)
#     167                         if np.sign(moves[i+1]['y'] - moves[i]['y']) != np.sign(moves[i]['y'] - moves[i-1]['y']) or np.sign(moves[i+1]['x'] - moves[i]['x']) != np.sign(moves[i]['x'] - moves[i-1]['x']):
#     168                             self.show()
# --> 169                             raise ValueError("Can't change your direction here")
#     170
#     171
#
# ValueError: Can't change your direction here

# %% [markdown]
# ##
